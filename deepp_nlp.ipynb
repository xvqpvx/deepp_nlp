# %%
pip install deeppavlov
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from deeppavlov import configs, build_model
model = build_model(configs.classifiers.rusentiment_convers_bert, download=True, load_trained=True)
# Out:
# 2022-11-20 14:13:30.906 INFO in 'deeppavlov.core.data.utils'['utils'] at line 95: Downloading from http://files.deeppavlov.ai/v1/classifiers/rusentiment_convers_bert/rusentiment_convers_bert_torch.tar.gz to C:\Users\vadim\.deeppavlov\models\classifiers\rusentiment_convers_bert_torch.tar.gz
# 2022-11-20 14:13:32.627 WARNING in 'deeppavlov.core.data.utils'['utils'] at line 114: Found a partial download C:\Users\vadim\.deeppavlov\models\classifiers\rusentiment_convers_bert_torch.tar.gz.part
#  14%|████████████▍                                                                         | 219M/1.52G [00:00<?, ?B/s]2022-11-20 14:13:32.629 WARNING in 'deeppavlov.core.data.utils'['utils'] at line 118: Download stopped abruptly, trying to resume from 218595014 to reach 1517086330
# ...

# %%
text = "Ты дурачок"
model([text])
# Out:
# ['negative']

# %%
text = "Ты молодец"
model([text])
# Out:
# ['positive']
